# %%
# !pip install xlrd

# %%
import pandas as pd

df= pd.read_excel('출생률.xls', skiprows=2, nrows=2, index_col=0)
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019    2020
# 출생아 수   302.700  272.30
# 합계 출산율    0.918    0.84

# %%
df.index.values # 인덱스 확인

df.rename(index={'출생아\xa0수':'출생아 수','합계\xa0출산율':'합계 출생률'}, inplace=True)

# 데이터 row, columns 변경
df = df.transpose()

# %%
# 데이터시각화 설정
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'NANUMGOTHICLIGHT' # 글씨폰트 설정
matplotlib.rcParams['font.size'] = 15 # 글자크기 설정
matplotlib.rcParams['axes.unicode_minus'] = False # 한글코드 사용 시 마이너스 글자 깨짐 방지

# %%
# 데이터 시각화
fig,ax1 = plt.subplots(figsize=(10,8))
ax1.plot(df_t.index, df_t['출생아 수'], color='red')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 완성
ax2.plot(df_t.index, df_t['합계 출생률'])

# %%
fig,ax1 = plt.subplots(figsize=(10,8))
ax1.set_ylabel('출생아 수(천 명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300, 400, 500, 600])
ax1.bar(df.index, df['출생아 수'], color='orange')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 완성
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출생률(가임여성 1명 당)')
ax2.plot(df.index, df['합계 출생률'])
# Out:
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
fig,ax1 = plt.subplots(figsize=(10,8))
fig.suptitle('출생아 수 및 합계출산율')
ax1.set_ylabel('출생아 수(천 명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300, 400, 500, 600])
ax1.bar(df.index, df['출생아 수'], color='orange')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 3, val, ha='center')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 완성
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출생률(가임여성 1명 당)')
ax2.plot(df.index, df['합계 출생률'], marker='o', ms=15, lw=2, mec='w', mew = 3)
for idx, val in enumerate(df['합계 출생률']):
    ax2.text(idx, val+0.05, val,  ha='center')
# Out:
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Miniconda3\envs\kwonjh\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
